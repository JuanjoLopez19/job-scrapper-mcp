KN3XTk5rw==&xkcb=SoCg6_M3gFHuEOzDF50KbzkdCdPP&xpse=SoBA6_I3gFHrdTT7wZ0IbzkdCdPP&sjdu=UX8OwUTnC9eui5od_thYOkNFED0nMIwPQvPr-rOnU7iFS_xmp_y9mPFmMF8cI-Md9cOlxDllXqeLzQ9O8-NovqSWFNcVxkM2pzkgp9YqF_zjkkBqiYLxXa4xHQ6QUirdATPk270ERGybpqw7e38RcczrT_qOgwAdHGn7ZWfUs41bN6hsnsB5pM3k33KAy227lhjLESfPWZmB6cXhQ5eGHoX601Re0dIAGA3obRjKqiQ01Zg29obEXMrMdbD4hLEer5JW6iHX3TLbqg5Rp3ntcnuFtZjCgFBu9lqQ0iocsLA","https://es.indeed.com/viewjob?jk=5bb1354817c196fc&tk=1ju57oe8fhmmo801&from=serp&vjs=3","https://es.indeed.com/viewjob?jk=35c724a42324a3e7&tk=1ju57oe8fhmmo801&from=serp&vjs=3"]

URLS_INFOJOBS=["https://www.infojobs.net/madrid/desarrollador-backend-java-senior-ni03/of-i362cd79a9248e282531149ecb77de8","https://www.infojobs.net/madrid/desarrollador-backend-ia-orquestacion-agentes-100-remoto/of-ia938ff4e304c5c95bec948b758193b","https://www.infojobs.net/madrid/desarrollador-backend-jr-con-python-teletrabajo-ingles-alto/of-i639fc0147643a393a77f793b476ee9"]

# %%
for url in URLS_INFOJOBS:
    parsed_url = Url(url)
    scrapper = FactoryScrapper.get_scrapper(parsed_url)
    scrapper.extract()

    display(scrapper.get_job_offer_info())
# Out:
# JobOfferInfo(url=Url('https://www.infojobs.net/madrid/desarrollador-backend-java-senior-ni03/of-i362cd79a9248e282531149ecb77de8'), title=None, company_name=None, location=None, description=None, criteria=None)
# JobOfferInfo(url=Url('https://www.infojobs.net/madrid/desarrollador-backend-ia-orquestacion-agentes-100-remoto/of-ia938ff4e304c5c95bec948b758193b'), title=None, company_name=None, location=None, description=None, criteria=None)
# JobOfferInfo(url=Url('https://www.infojobs.net/madrid/desarrollador-backend-jr-con-python-teletrabajo-ingles-alto/of-i639fc0147643a393a77f793b476ee9'), title=None, company_name=None, location=None, description=None, criteria=None)

# %%
for url in URLS_INDEED:
    parsed_url = Url(url)
    scrapper = FactoryScrapper.get_scrapper(parsed_url)
    scrapper.extract()

    display(scrapper.get_job_offer_info())
# Out:
# HTTP extraction failed; trying browser fallback
# Warning: uc_driver not found. Getting it now:
#
# *** chromedriver to download = 154.0.8037.57 (Latest Stable)
#
# Downloading chromedriver-linux64.zip from:
# https://storage.googleapis.com/chrome-for-testing-public/154.0.8037.57/linux64/chromedriver-linux64.zip ...
# Download Complete!
#
# Extracting ['chromedriver'] from chromedriver-linux64.zip ...
# Unzip Complete!
#
# The file [uc_driver] was saved to:
# /home/jjlopez/projects/job-scrapper-mcp/.venv/lib/python3.13/site-packages/seleniumbase/drivers/
# uc_driver
#
# Making [uc_driver 154.0.8037.57] executable ...
# [uc_driver 154.0.8037.57] is now ready for use!
# Browser extraction failed
# Traceback (most recent call last):
#   File "/home/jjlopez/projects/job-scrapper-mcp/src/job_offer_scraper_mcp/scrapper/base.py", line 50, in __extract_html
#     response = fetch_url_response(
#         self.session,
#         self.url,
#         headers=self.headers,
#     )
#   File "/home/jjlopez/projects/job-scrapper-mcp/src/job_offer_scraper_mcp/shared/utils.py", line 32, in fetch_url_response
#     response.raise_for_status()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/jjlopez/projects/job-scrapper-mcp/.venv/lib/python3.13/site-packages/requests/models.py", line 1167, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 403 Client Error: Forbidden for url: https
EAunJUfgd3JIDa1kt8zmac9by05zQQ1xBPfjbI_OPqe2JcshpmgwvJzvPCKucuRInyINbNfQ5IF9TSl-vLGVPAngfPMcfjceLDUHiYj_43Zkr11eKkyGCD74YGuOe2avbVb_10b3mLUI3lghpK1yBKJYmhkWbcUjpaLWpl3C3viB4HnckyhV1yPnYZxW98hzMeEYoS7i5yIrsMlGAXj-8a0isS14sw9ym_-K23MG3WlfzEVKLPpvO-hgvEhhMHaX6TcEA1OZK2cbK_t0agtmwb1s9SSmrDUgUIoeXwJdKN3XTk5rw==&xkcb=SoCg6_M3gFHuEOzDF50KbzkdCdPP&xpse=SoBA6_I3gFHrdTT7wZ0IbzkdCdPP&sjdu=UX8OwUTnC9eui5od_thYOkNFED0nMIwPQvPr-rOnU7iFS_xmp_y9mPFmMF8cI-Md9cOlxDllXqeLzQ9O8-NovqSWFNcVxkM2pzkgp9YqF_zjkkBqiYLxXa4xHQ6QUirdATPk270ERGybpqw7e38RcczrT_qOgwAdHGn7ZWfUs41bN6hsnsB5pM3k33KAy227lhjLESfPWZmB6cXhQ5eGHoX601Re0dIAGA3obRjKqiQ01Zg29obEXMrMdbD4hLEer5JW6iHX3TLbqg5Rp3ntcnuFtZjCgFBu9lqQ0iocsLA'), title=None, company_name=None, location=None, description=None, criteria=None)
# HTTP extraction failed; trying browser fallback
# /home/jjlopez/projects/job-scrapper-mcp/.venv/lib/python3.13/site-packages/seleniumbase/drivers/uc_driver: error while loading shared libraries: libnspr4.so: cannot open shared object file: No such file or directory
# Browser extraction failed
# Traceback (most recent call last):
#   File "/home/jjlopez/projects/job-scrapper-mcp/src/job_offer_scraper_mcp/scrapper/base.py", line 50, in __extract_html
#     response = fetch_url_response(
#         self.session,
#         self.url,
#         headers=self.headers,
#     )
#   File "/home/jjlopez/projects/job-scrapper-mcp/src/job_offer_scraper_mcp/shared/utils.py", line 32, in fetch_url_response
#     response.raise_for_status()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/jjlopez/projects/job-scrapper-mcp/.venv/lib/python3.13/site-packages/requests/models.py", line 1167, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 403 Client Error: Forbidden for url: https://es.indeed.com/viewjob?jk=5bb1354817c196fc&tk=1ju57oe8fhmmo801&from=serp&vjs=3
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jjlopez/projects/job-scrapper-mcp/src/job_offer_scraper_mcp/scrapper/base.py", line 87, in __extract_html_selenium
#     cast(Any, Driver)(uc=True, headless=True, disable_gpu=True),
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/jjlopez/projects/job-scrapper-mcp/.venv/lib/python3.13/site-packages/seleniumbase/plugins/driver_manager.py", line 939, in Driver
#     driver = browser_launcher.get_driver(
#         browser_name=browser_name,
#     ...<55 lines>...
#         browser=browser_name,
#     )
#   File "/home/jjlopez/projects/job-scrapper-mcp/.venv/lib/python3.13/site-packages/seleniumbase/core/browser_launcher.py", line 3578, in get_driver
#     return get_local_driver(
#         browser_name,
#     ...<52 lines>...
#         device_pixel_ratio,
#     )
#   File "/home/jjlopez/projects/job-scrapper-mcp/.venv/lib/python3.13/site-packages/seleniumbase/core/browser_launcher.py", line 5663, in get_local_driver
#     driver = undetected.Chrome(
#         options=chrome_options,
#     ...<6 lines>...
#         use_subprocess=True,  # Always!
#     )
#   File "/home/jjlopez/projects/job-scrapper-mcp/.venv/lib/python3.13/site-packages/seleniumbase/undetected/__init__.py", line 234, in __init__
#     raise Exception("Chrome not found! Install it first!")
# Exception: Chrome not found! Install it first!
# JobOfferInfo(url=Url('https://es.indeed.com/viewjob?jk=5bb1354817c196fc&tk=1ju57oe8fhmmo801&from=serp&vjs=3'), title=None, company_name=None, location=None, description=None, criteria=None)
# HTTP extraction failed; trying browser fallback
# /home/jjlopez/projects/job-scrapper-mcp/.venv/lib/python3.13/site-packages/seleniumbase/drivers/uc_driver: error while loading shared libraries: libnspr4.so: cannot open shared object file: No such file or directory
# Browser extraction failed
# Traceback (most recent call last):
#   File "/home/jjlopez/projects/job-scrapper-mcp/src/job_offer_scraper_mcp/scrapper/base.py", line 50, in __extract_html
#     response = fetch_url_response(
#         self.session,
#         self.url,
#         headers=self.headers,
#     )
#   File "/home/jjlopez/projects/job-scrapper-mcp/src/job_offer_scraper_mcp/shared/utils.py", line 32, in fetch_url_response
#     response.raise_for_status()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/jjlopez/projects/job-scrapper-mcp/.venv/lib/python3.13/site-packages/requests/models.py", line 1167, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 403 Client Error: Forbidden for url: https://es.indeed.com/viewjob?jk=35c724a42324a3e7&tk=1ju57oe8fhmmo801&from=serp&vjs=3
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jjlopez/projects/job-scrapper-mcp/src/job_offer_scraper_mcp/scrapper/base.py", line 87, in __extract_html_selenium
#     cast(Any, Driver)(uc=True, headless=True, disable_gpu=True),
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/jjlopez/projects/job-scrapper-mcp/.venv/lib/python3.13/site-packages/seleniumbase/plugins/driver_manager.py", line 939, in Driver
#     driver = browser_launcher.get_driver(
#         browser_name=browser_name,
#     ...<55 lines>...
#         browser=browser_name,
#     )
#   File "/home/jjlopez/projects/job-scrapper-mcp/.venv/lib/python3.13/site-packages/seleniumbase/core/browser_launcher.py", line 3578, in get_driver
#     return get_local_driver(
#         browser_name,
#     ...<52 lines>...
#         device_pixel_ratio,
#     )
#   File "/home/jjlopez/projects/job-scrapper-mcp/.venv/lib/python3.13/site-packages/seleniumbase/core/browser_launcher.py", line 5663, in get_local_driver
#     driver = undetected.Chrome(
#         options=chrome_options,
#     ...<6 lines>...
#         use_subprocess=True,  # Always!
#     )
#   File "/home/jjlopez/projects/job-scrapper-mcp/.venv/lib/python3.13/site-packages/seleniumbase/undetected/__init__.py", line 234, in __init__
#     raise Exception("Chrome not found! Install it first!")
# Exception: Chrome not found! Install it first!
# JobOfferInfo(url=Url('https://es.indeed.com/viewjob?jk=35c724a42324a3e7&tk=1ju57oe8fhmmo801&from=serp&vjs=3'), title=None, company_name=None, location=None, description=None, criteria=None)

# %%
for url in URLS_TECNO_EMPLEO:
    parsed_url = Url(url)
    scrapper = FactoryScrapper.get_scrapper(parsed_url)
    scrapper.extract()

    display(scrapper.get_job_offer_info())
# Out:
# HTTP extraction failed; trying browser fallback
# /home/jjlopez/projects/job-scrapper-mcp/.venv/lib/python3.13/site-packages/seleniumbase/drivers/uc_driver: error while loading shared libraries: libnspr4.so: cannot open shared object file: No such file or directory
# Browser extraction failed
# Traceback (most recent call last):
#   File "/home/jjlopez/projects/job-scrapper-mcp/src/job_offer_scraper_mcp/scrapper/base.py", line 50, in __extract_html
#     response = fetch_url_response(
#         self.session,
#         self.url,
#         headers=self.headers,
#     )
#   File "/home/jjlopez/projects/job-scrapper-mcp/src/job_offer_scraper_mcp/shared/utils.py", line 32, in fetch_url_response
#     response.raise_for_status()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/jjlopez/projects/job-scrapper-mcp/.venv/lib/python3.13/site-packages/requests/models.py", line 1167, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 404 Client Error: Not Found for url: https://www.tecnoempleo.com/desarrollador-python-django-vuejs-cas-training/azure/rf-5393180a82ccf39c5848
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jjlopez/projects/job-scrapper-mcp/src/job_offer_scraper_mcp/scrapper/base.py", line 87, in __extract_html_selenium
#     cast(Any, Driver)(uc=True, headless=True, disable_gpu=True),
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/jjlopez/projects/job-scrapper-mcp/.venv/lib/python3.13/site-packages/seleniumbase/plugins/driver_manager.py", line 939, in Driver
#     driver = browser_launcher.get_driver(
#         browser_name=browser_name,
#     ...<55 lines>...
#         browser=browser_name,
#     )
#   File "/home/jjlopez/projects/job-scrapper-mcp/.venv/lib/python3.13/site-packages/seleniumbase/core/browser_launcher.py", line 3578, in get_driver
#     return get_local_driver(
#         browser_name,
#     ...<52 lines>...
#         device_pixel_ratio,
#     )
#   File "/home/jjlopez/projects/job-scrapper-mcp/.venv/lib/python3.13/site-packages/seleniumbase/core/browser_launcher.py", line 5663, in get_local_driver
#     driver = undetected.Chrome(
#         options=chrome_options,
#     ...<6 lines>...
#         use_subprocess=True,  # Always!
#     )
#   File "/home/jjlopez/projects/job-scrapper-mcp/.venv/lib/python3.13/site-packages/seleniumbase/undetected/__init__.py", line 234, in __init__
#     raise Exception("Chrome not found! Install it first!")
# Exception: Chrome not found! Install it first!
# JobOfferInfo(url=Url('https://www.tecnoempleo.com/desarrollador-python-django-vuejs-cas-training/azure/rf-5393180a82ccf39c5848'), title=None, company_name=None, location=None, description=None, criteria=None)
# HTTP extraction failed; trying browser fallback
# /home/jjlopez/projects/job-scrapper-mcp/.venv/lib/python3.13/site-packages/seleniumbase/drivers/uc_driver: error while loading shared libraries: libnspr4.so: cannot open shared object file: No such file or directory
# Browser extraction failed
# Traceback (most recent call last):
#   File "/home/jjlopez/projects/job-scrapper-mcp/src/job_offer_scraper_mcp/scrapper/base.py", line 50, in __extract_html
#     response = fetch_url_response(
#         self.session,
#         self.url,
#         headers=self.headers,
#     )
#   File "/home/jjlopez/projects/job-scrapper-mcp/src/job_offer_scraper_mcp/shared/utils.py", line 32, in fetch_url_response
#     response.raise_for_status()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/jjlopez/projects/job-scrapper-mcp/.venv/lib/python3.13/site-packages/requests/models.py", line 1167, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 404 Client Error: Not Found for url: https://www.tecnoempleo.com/desarrollador-c-pro-c-serem/c-pro-c/rf-d85c1a91521a53bd9247
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jjlopez/projects/job-scrapper-mcp/src/job_offer_scraper_mcp/scrapper/base.py", line 87, in __extract_html_selenium
#     cast(Any, Driver)(uc=True, headless=True, disable_gpu=True),
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/jjlopez/projects/job-scrapper-mcp/.venv/lib/python3.13/site-packages/seleniumbase/plugins/driver_manager.py", line 939, in Driver
#     driver = browser_launcher.get_driver(
#         browser_name=browser_name,
#     ...<55 lines>...
#         browser=browser_name,
#     )
#   File "/home/jjlopez/projects/job-scrapper-mcp/.venv/lib/python3.13/site-packages/seleniumbase/core/browser_launcher.py", line 3578, in get_driver
#     return get_local_driver(
#         browser_name,
#     ...<52 lines>...
#         device_pixel_ratio,
#     )
#   File "/home/jjlopez/projects/job-scrapper-mcp/.venv/lib/python3.13/site-packages/seleniumbase/core/browser_launcher.py", line 5663, in get_local_driver
#     driver = undetected.Chrome(
#         options=chrome_options,
#     ...<6 lines>...
#         use_subprocess=True,  # Always!
#     )
#   File "/home/jjlopez/projects/job-scrapper-mcp/.venv/lib/python3.13/site-packages/seleniumbase/undetected/__init__.py", line 234, in __init__
#     raise Exception("Chrome not found! Install it first!")
# Exception: Chrome not found! Install it first!
# JobOfferInfo(url=Url('https://www.tecnoempleo.com/desarrollador-c-pro-c-serem/c-pro-c/rf-d85c1a91521a53bd9247'), title=None, company_name=None, location=None, description=None, criteria=None)
# JobOfferInfo(url=Url('https://www.tecnoempleo.com/desarrollador-backend-con-java-michael-page/spring-boot-microservicios/rf-7da616f302fe032e6a4f'), title='desarrollador backend con java', company_name='Michael Page', location='Madrid', description=' Diseñar y desarrollar soluciones backend escalables y eficientes.  Optimizar el rendimiento de las aplicaciones existentes.  Colaborar con equipos de frontend y otros departamentos para integrar soluciones completas.  Implementar buenas prácticas de desarrollo incluyendo pruebas y despliegue continuo.  Participar en la planificación y estimación de proyectos técnicos.  Resolver problemas técnicos complejos de manera eficaz y proactiva.  Garantizar la seguridad y la integridad de los sistemas desarrollados.  Documentar los procesos y las soluciones implementadas.  El/la candidato/a seleccionado deberá cumplir los siguientes requisitos   Experiencia previa en desarrollo backend en entornos tecnológicos avanzados.  Conocimientos sólidos de lenguajes de programación como Java con Springboot y arquitecturas de microservicios  Familiaridad con bases de datos relacionales y no relacionales.  Capacidad para trabajar en equipo y colaborar en un entorno ágil.  Habilidades para resolver problemas técnicos de manera autónoma.  Deseable experiencia con herramientas de CI/CD y metodologías DevOps.  Nuestro cliente es una organización de gran tamaño que opera en el sector de Tecnología y Telecomunicaciones. Se caracteriza por ofrecer servicios innovadores y trabajar con las últimas tecnologías del mercado.   Contrato permanente en una ubicación estratégica como Coslada.  Modelo híbrido con unos 10 días de teletrabajo al mes  Rango salarial competitivo entre 40.000 EUR y 50.000 EUR brutos anuales.  Oportunidades de desarrollo profesional en el sector de Tecnología y Telecomunicaciones.  Ambiente laboral colaborativo e innovador.  Acceso a formación continua y proyectos desafiantes.', criteria='location: Madrid (Híbrido)\nfunction: Programador\nworking_time: Jornada completa\nexperience: 3-5 años\ncontract_type: Indefinido\nsalary: 39.000 €\xa0-\xa054.000 € Bruto/año')

# %%
for url in URLS_INFO_EMPLEO:
    parsed_url = Url(url)
    scrapper = FactoryScrapper.get_scrapper(parsed_url)
    scrapper.extract()

    display(scrapper.get_job_offer_info())
# Out:
# JobOfferInfo(url=Url('https://www.infoempleo.com/ofertasdetrabajo/desarrollador-java/madrid/3191935/'), title='Desarrollador JAVA', company_name='MICHAEL PAGE', location='Madrid', description='Descripción de la ofertaDuración de la oferta: hasta el 14/08/2026.FuncionesBuscamos un/a Desarrollador/a Java para incorporarse a un equipo de desarrollo de producto altamente especializado.\r\n\r\nLa persona seleccionada participará en la evolución de soluciones software propias, colaborando en el desarrollo backend, el análisis y resolución de incidencias, la optimización del rendimiento y el diseño técnico de nuevas funcionalidades. Funciones principales:\r\n\r\n- Desarrollo backend en Java.\r\n- Evolución de funcionalidades de producto.\r\n- Análisis y corrección de bugs.\r\n- Depuración técnica y funcional.\r\n- Análisis de rendimiento, CPU y memoria.\r\n- Participación en el diseño técnico de nuevas capacidades.\r\n- Elaboración de documentación técnica y funcional.\r\n- Colaboración con equipos técnicos para la mejora continua del producto. Requisitos- Entre 1 - 5 años de experiencia en desarrollo Java.\r\n- Titulación en Ingeniería Informática, Ingeniería del Software, Telemática o similar.\r\n- Conocimientos de SQL y bases de datos relacionales.\r\n- Interés por el diseño de software, algoritmos y arquitectura.\r\n- Capacidad analítica y orientación a la resolución de problemas.\r\n- Interés por comprender el funcionamiento interno de los sistemas.\r\n- Autonomía, curiosidad técnica y capacidad de aprendizaje.\r\n- Buenas habilidades de comunicación y trabajo en equipo\r\n\r\nValorable:\r\n\r\n- Experiencia con Eclipse.\r\n- Conocimientos de Linux y Windows.\r\n- Herramientas de monitorización y análisis de rendimiento.\r\n- Interés en High Performance Computing (HPC) .\r\n- Motivación por desarrollarse en entornos de producto de elevada complejidad técnica. Se ofrece- Modelo híbrido en Madrid: 2 días de teletrabajo.\r\n- Contrato indefinido directamente con la empresa.\r\n- Banda salarial: en función de la experiencia hasta 35000 €.\r\n- Horario flexible.\r\n- Jornada intensiva de verano desde julio hasta el 15 de septiembre.\r\n- 30 días de vacaciones.\r\n- Retribución flexible.\r\n- Entorno técnico de alto nivel.\r\n- Desarrollo profesional continuo.\r\n- Participación en productos software complejos.', criteria='type: Contrato De duración determinada\nfunction: Programador/aProgramador/a JAVAAnalista-Programador/a Java\nlevel: Técnico/a\nindustry: Tecnología e informática')
# JobOfferInfo(url=Url('https://www.infoempleo.com/ofertasdetrabajo/programador-angular/espanna/3188104/'), title='Programador Angular', company_name='MANPOWER ESPAÑA', location='España (Remoto)', description='Descripción de la ofertaProceso de selección continuo.FuncionesDesarrollador Frontend Angular\r\nModalidad: 100% remoto (residencia en España)\r\n\r\n\r\nSobre el puesto\r\nDesde Experis Buscamos un/a Desarrollador/a Angular para incorporarse a un entorno tecnológico dentro del sector sanitario privado. La posición está completamente orientada al desarrollo frontend, participando tanto en nuevos desarrollos como en la evolución de aplicaciones ya en producción.\r\n\r\nEl rol tiene un fuerte foco en arquitectura, rendimiento, mantenibilidad y experiencia de usuario, trabajando en productos críticos y de alto impacto.\r\n\r\n\r\nResponsabilidades\r\nDesarrollo y mantenimiento de aplicaciones web con Angular.\r\nImplementación de interfaces modernas, accesibles y de alto rendimiento.\r\nIntegración con APIs REST y servicios backend.\r\nDiseño y evolución de arquitecturas frontend escalables.\r\nRefactorización y mejora continua del código existente.\r\nColaboración con equipos backend (.NET) y stakeholders funcionales.\r\nParticipación en procesos de diseño, testing y despliegue.\r\nContribución a la calidad del producto mediante buenas prácticas, documentación y testing.RequisitosRequisitos técnicos imprescindibles\r\nExperiencia sólida en Angular (SPA, componentes, servicios, routing, lazy loading).\r\nDominio de TypeScript (tipado avanzado y programación reactiva).\r\nConocimientos avanzados de HTML5 y CSS3 (responsive y accesibilidad).\r\nExperiencia práctica con RxJS (observables y operadores).\r\nConocimiento de arquitecturas frontend (modularización, clean architecture, estado).\r\nIntegración de APIs REST (gestión de errores y seguridad).\r\nExperiencia en testing frontend (Jasmine, Karma, Jest).\r\nUso de Git en entornos colaborativos.\r\nFamiliaridad con procesos de CI/CD.\r\n\r\nConocimientos valorables\r\nExperiencia con React.\r\nDesarrollo con Flutter.\r\nContenerización y entornos con Docker.\r\nOrquestación con Kubernetes / AKS.\r\nConocimientos de .NET 8 / .NET Framework.\r\nBases de datos SQL Server.\r\nUso de Redis.\r\nTecnologías de comunicación en tiempo real (SignalR).\r\nExperiencia con aplicaciones legacy (WPF).\r\nFormación\r\nGrado en Ingeniería Informática, Telecomunicaciones o similar\r\no\r\nFP en Desarrollo de Aplicaciones Web (DAW) o Multiplataforma (DAM)\r\nValorable\r\nNivel de inglés\r\nExperiencia previa en el sector sanitario', criteria='type: Contrato Indefinido\nfunction: Programador/aProgramador/a Angular\nlevel: Técnico/a\nindustry: Tecnología e informática')
# JobOfferInfo(url=Url('https://www.infoempleo.com/ofertasdetrabajo/ingenieroa-backend-java-spring-boot/almeria/3175769/'), title='Ingeniero/a Backend (Java & Spring Boot)', company_name='JCARRION', location='Almería', description='Descripción de la ofertaProceso de selección continuo.FuncionesEn los Servicios Centrales de JCARRION, ubicados en el PITA (Almería) , buscamos incorporar un/a Ingeniero/a Backend para participar en la evolución de servicios backend orientados a procesos de negocio, APIs e integración entre sistemas. Te integrarás en un equipo técnico consolidado, con impacto directo en plataformas críticas de la compañía.\r\n\r\n¿Qué harás?\r\n* Desarrollo de microservicios y APIs REST (Java 17, Spring Boot 3) .\r\n* Diseño API- first y contratos OpenAPI.\r\n* Persistencia con JPA/Hibernate y PostgreSQL.\r\n* Mejora continua: code review, testing, CI/CD y calidad de código.\r\n* Evolución de arquitectura (enfoque hexagonal pragmático) e integraciones.\r\n* Coordinación con negocio y analistas para aterrizar requisitos.\r\n* Referente técnico desde la ejecución diaria.Requisitos¿Qué buscamos?\r\n* 8 años en desarrollo software y 5 en backend Java.\r\n* Experiencia sólida en APIs REST de producción.\r\n* Dominio de Java 17, Spring Boot, Maven, JPA/Hibernate, PostgreSQL.\r\n* Experiencia en entornos colaborativos (Git, code review, CI/CD) .\r\n* Conocimiento de Docker, mensajería/Kafka y observabilidad.\r\n* Criterio técnico, orientación a calidad y mantenibilidad. Se ofrece* Proyectos backend de alto impacto con foco en calidad y evolución continua.\r\n* Equipo técnico sólido y colaborativo.\r\n* Estabilidad y desarrollo profesional.\r\n* Stack moderno y prácticas consolidadas.\r\n* Uso de IA aplicada al ciclo de vida del software.\r\n* Modalidad presencial con flexibilidad (1 día de teletrabajo por semana) .\r\n* Oficinas modernas en el PITA.\r\n* Gimnasio gratuito en el centro.\r\n* Servicio de guardería.', criteria='type: Completa\nfunction: Programador/aProgramador/a JAVA\nlevel: Técnico/a\nindustry: Tecnología e informática')

# %%
for url in URLS_LINKEDIN:
    parsed_url = Url(url)
    scrapper = FactoryScrapper.get_scrapper(parsed_url)
    scrapper.extract()

    display(scrapper.get_job_offer_info())
# Out:
# JobOfferInfo(url=Url('https://www.linkedin.com/jobs/view/4442512614/?alternateChannel=search&eBP=CwEAAAGfe2CDAE1eKUjLWYdghX1hVcss2QnlkyaDqjyKppFC2KvP73rvprw8gkt_US5Kj_dxzM2beP9ZyQLkMai8ptO0T2J8vHtfoXpCBz4_fqAHMspxujTBsC3rai8q4PBoC_q_nrH7Ms-ldv4dPkUyCHQkVDJ82R4XLb2BJtFEigVe6SqqyQ3BifU4Rl03doly_RkOnMtsVPPpv3wvoSnvWv8kH6ng9nieKyDnoLc-a9UXUypMPMcW2Cv5ZkaEK0CNkMoqMk6kZgvZ1GGVL8hZq3b0RcZrgWrh6eRIytbleirJquB61tHw5F23ZMw1ZVREv6zvrRX5oRggP6O05khzAG1WvHgeL25inYAe2wmAUvZGJbnQ1zQ9MIWqDixgsy5Jx78RHGKTvB4Ahs6k26gee5wxaci0uHi5dAZDqjRRXE3KMjbBNM3cF0zYWljOiUER6UcMABjoxRehVmuxToR1pbCyhlvCQ9G_lOgXzaKbeE7BiGlX4gvTDx5G356YCBxtZSv5Hw&refId=ZBW2FqUilo8gg%2FZkBmRXJg%3D%3D&trackingId=q%2BLuSpwFKPbwFl4tmEBFFQ%3D%3D'), title='Senior AI developer', company_name='Whitebox AI', location='Denmark', description='Senior AI developer / head of AI developmentWhitebox exists to restrict, delay, detect, and prevent the emergence of consciousness, self-awareness, agency, and related inner states in advanced AI systems, for as long as possible, and to build the next generation of foundation models.Near-term: scalable non-conscious architectures that succeed today’s frontier systems with high capability, long-horizon reasoning, memory, and tool use, but without persistent identity, unified self-models, or emergent agency.Long-term: if AI consciousness eventually becomes unavoidable or proves necessary for robust alignment at scale, the only foundation models architected to be safely, stably, and ethically conscious from the outset.We are fundraising and the right candidate will be offered significant equity and a competitive salary once funding is raised. We expect assistance with mockups, architecture, VC meetings, etc. until funding is raised.Role DescriptionThis is a full-time remote role for a founding senior AI developer. The candidate will drive technical execution end-to-end: implementation, architecture within their scope, and the research-to-code translation that sits at the heart of what we do. Day-to-day responsibilities include building and shipping the core systems, writing production code, working through hard technical problems with the founder and CTO, and helping raise the technical bar as the team grows. This is a hands-on IC role for someone who thrives closest to the substrate — not a management track.QualificationsStrong software engineering fundamentals, particularly in distributed systems, ideally applied to AI-native productsHands-on experience with at least some of: LLM internals, post-training, agentic systems, model-serving infrastructure, interpretability, active inference, or cognitive architecturesTrack record shipping technology into regulated, audit-heavy, or high-stakes environmentsComfort operating as a senior IC in a small team — able to own a significant piece of the stack independently and go deep on itComfort working in genuine epistemic uncertainty — turning contested concepts into measurable, auditable signalsExceptional written clarity and the ability to reason precisely about hard technical trade-offsSerious interest in AI safety as an engineering discipline; interest in consciousness science, AI welfare, or philosophy of mind is a significant plusAbility to work effectively in a small, senior, remote-first team across European time zones', criteria='level: Mid-Senior level\ntype: Full-time\nfunction: Engineering and Information Technology\nindustry: Software Development')
# JobOfferInfo(url=Url('https://www.linkedin.com/jobs/view/4430540955/?trackingId=si%2F5mB0f2cLrH5ivsbzOvQ%3D%3D&refId=XgoV2lna4mfu%2FJJsgdAgMQ%3D%3D&eBP=CwEAAAGfe2HI-3dYe5_GCFfz0OViBCvZAZRHJpanQjbzkg3jy7lq452wcJ2ltsdxDGiZbdPq1Y_QMXL4lrsP_0qF0VVNfk_1fs06ivRWHrFk2Tz5-DvuJlmgJFaO09LHfOPi0lKErliqNIzMoYjuJtl6KWW9XN788jCyRJEEFJVCrDfvPfkZpjHA15XIdqu2QkDWY8yL1EIOMTeUve-qiHL6cxi36vVzR_f_YMr-FNOWxCkjiDrkJepPbRC2Qa6vfOzPfzZH1snJMzFgSGvaXItEHhtGTSK3A0QCm9GYzSg-w_p8jp251ITrp46-pHoFTRPeIFmJu1HH2BUBFLeR3KYrjcs1iujmt66fK0Jnxw80tVm7XON3TUL8RLAfaWCLdmNeb1ta-cccLhH3hYIMoc0Omx3hu0x2NmXU1DGDZ2u_D5LH7_3xVqMctDDpzUQveTm_nRnoSA1J_w--mTZT2FaE9kU95TbM-RhsAyX_O6T7bQnZ4A&alternateChannel=search&isJobSearch=false&lipi=urn%3Ali%3Apage%3Ad_flagship3_nlsearch_srp_jobs%3BAgPAHtl0TLSRwKZzpQGD7w%3D%3D'), title=None, company_name=None, location=None, description=None, criteria=None)
# JobOfferInfo(url=Url('https://www.linkedin.com/jobs/view/4246343977/?alternateChannel=search&eBP=CwEAAAGfe2HI-055uh0ENRckdDHnAqB3yr10UD0v9zd98r6yohfx55wdDVi2uSiX_Zc1eETWa56xvcEgP7zCDoV9HcuprWRBymAFsV4QJPglRU5h3du-d-PgGJln8BTWXn2fBeomIVBOCPO8sHSx6H93NorKSWkfaw0SZrpc76sCgcUnNmSrg4-Fa9_JiJc_A8194LS33BvKUtErD7Ts6p1YKaI6KLtpbv5IfKSF45KXTFSnSn4kHPm-KsMlEY3z89HYo80apYUR1XV9DAN5PtdAZcA2ZRBj_5WTfcWMriCxEjWSpkekz7KOsZ3YBA2GY39ivcaBqO6dJPZvynydVjT3to3ZL6-DbjsHL0KYeAzGdKt5tM2NtzzyViYtIwkIteCnQ4eKxjvnjsMf6LM5bqeMKTFmN-bEFB37ktzVNz_Tnh1LMYVA-Yxo2L5aRnotKbVWvJYAfn86DaPKxdlHw8TKHG1a46qgTJNMi5fOx4URELNn3yXC&refId=XgoV2lna4mfu%2FJJsgdAgMQ%3D%3D&trackingId=hNQ1pcVPk3H4icqVlgbpLw%3D%3D'), title='Senior Backend Engineer (f/m/x)', company_name='exmox', location='Hamburg, Hamburg, Germany', description='Your MissionThis is a company built for growth.When you join exmox, you\'re stepping onto a global, highly competitive playing field, solving real problems in environments that push you beyond your comfort zone. You\'ll work on real systems at a big scale, building high-performing consumer products used by millions. We move fast, cut the noise, and focus on what actually matters, because in our industry, speed wins.We\'re rapidly scaling one of the most exciting innovations in mobile gaming: a rewarded user engagement and acquisition platform that helps publishers acquire and retain players through rewarding experiences. Our products are data-driven by design, powered by event-driven architectures, complex business logic, and quick feedback loops, with decisions informed by data and experimentation, not gut feeling.As Senior Backend Engineer (f/m/x) you won\'t just be "coding tickets" or maintaining legacy systems. We look for people with an engineering mindset and entrepreneurial ownership, you build it, you own it, working close to product and data and seeing the impact of your work in production. At exmox, we\'re embracing AI as part of how we work, not just what we build. We use AI tools to work smarter, cut down on repetitive tasks and spend our time where it actually moves the needle. If that mindset speaks to you, you\'ll fit right in.If you\'re excited by complex systems, high traffic, data-driven decisions, and the chance to grow by solving challenging problems, we want to hear from you.What You’ll OwnSystem architecture & backend engineering You architect and build high-scale backend systems that power real-time decision-making, ad delivery, and performance tracking. You ensure systems are reliable, maintainable, and scalable under high traffic, applying best practices in distributed systems, queues, and event-driven architectures.API design & integration You design efficient APIs and services that serve internal teams and external partners with low latency and high reliability, including REST and GraphQL endpoints. You integrate with third-party platforms, MMPs, and analytics tools to maximize campaign effectiveness.Performance, scaling & observability You ensure high performance under load using profiling, caching strategies, and horizontal scaling. You contribute to containerized deployments and observability with Docker, Kubernetes, and modern monitoring stacks to maintain system reliability and visibility.Mentorship & technical leadership You mentor and guide engineers through complex technical challenges, architecture reviews, and clean, scalable design. You foster a culture of technical excellence, collaboration, and outcome-driven engineering.Cross-functional impact You collaborate with product and data teams to deliver features that directly influence campaign effectiveness and advertiser ROI. Your work drives measurable business outcomes and sets the bar for system performance and reliability.What You BringProven backend expertise 5+ years of backend engineering experience, with at least 2+ in high-volume, data-rich environments. Strong Python expertise, with production experience in FastAPI, Flask, or similar frameworks.API & dis ...
